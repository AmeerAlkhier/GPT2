# %% [markdown]
# <a href="https://colab.research.google.com/github/AmeerAlkhier/GPT2/blob/main/Generating_text_from_trained_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='run2')

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run2')
# Out:
# Loading checkpoint checkpoint/run2/model-5000
# INFO:tensorflow:Restoring parameters from checkpoint/run2/model-5000

# %% [markdown]
# Generate single text

# %%
gpt2.generate(sess, run_name='run2')
# Out:
# من الادمان على مشاعر المشاهدين ....
# لايزال الفديو غير ملائم لجميع المشاهدين مع ذلك ...فيرجى الحذر و التفكر قبل المشاهدة ....
# تحذير الصوت عالي بشكل سخيف....و يحتوي على jump scare .■ عاش هذه الجوكر في قضية الحجاب؟ما هي طقوس الحشيش المسرطن؟
#
# ■ كان يتعاطى كحال جميع المكسيكيين حبوب الحشيش المسرطن لم يعرف ما يجب على jump scare .
#
# ■ كان يعمل ان يشرعون على jump scare .
#
# ■ كان يحاول للمرة الشهير بالذكر ان يجعل كحال جميع المكسيكيين و الفائدة تماما منفصل غدد الاجتماعي و الخارجين بالريبة الشهير لتعاطي المفروض لنبات الحشيش المسرطن المريجونة.
#
# ■ طبعا هكذه الخوف على jump scare .
#
# معرفة واحدة في الحمراء الحوامل و الاخرين بالريبة كان يتعاطى الحشيش المسرطن ؟
# أعجبته رائحة النبات و انحدر و تماماما منفصل عن الواقع و تماما في الخلق لتشكيك حيث تحوي معنى لعين بشكل كلي حيث يستطيع هناك ان يتذوق الألوان أو انه يقوم بمداعبة الحوامل والحوان بدون حتى ان يقوم بمداعبة الحوان ...
# ...

# %%
gpt2.generate(sess,
              run_name='run2',
              length=1000,
              temperature=0.9,
              prefix=" ",
              nsamples=30,
              batch_size=5
              )
# Out:
#  سكري مثل المرأة الحامل و الجنين :
# ■ انقاص المناعة والخصوبة والاصابة بالجلطات في مختلف اعضاء الجسم ..
# ■ تشوهات الجنين المعروفة والولادة العسيرة وموت الام والأب والجنينTovábbiak أثناء المخاض.
# ■ حدوث طفرات جديدة في الحمض النووي للمولود ما يؤدي الى صفات وسلوكيات عجيبة مثل الميول لتعذيب الحيوانات الصغيرة وأكل جثثها. بالإضافة الى وعي أعلى وذكاء أكبر ولكن فقط فيما يخص الإجرام..
#
# الصورة حقيقية مأخوذة في ولاية ماستشوستس الأمير.كية المعروفة بانتشار المخدرات و الجريمة.
#
# هل هذ يمكنك ان يشعر بالسعادة ؟
# بالتأكيد يبدو وTovábbiak كأنه في عالم انه يرخي دوامة التعاطي بدقة وهي يدعى العلاج بدقة وهي يسرطن الأولى..
#
# ■ كان لدى العلاج في الشارع و الاضطرار الى التي يعطي المخدرات و الجريمة.
#
# ■ وقعت الشارع ولكنه يرخي دوامة التعاطي بدقة وهي يدعى العلاج بدقة وهي يسرطن بالكلام الفارغ و يجد اتفه الافكار كشيء عظيم ..
# الفديو ماخوذ من احد المخدرات يفقد القدرة على معرفة الاصوات و ليس هناك سوء نية باي شكل من الاشكال.
#
# ■ يشعر بالسعادة ؟
# ...
