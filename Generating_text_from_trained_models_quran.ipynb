# %% [markdown]
# <a href="https://colab.research.google.com/github/AmeerAlkhier/GPT2/blob/main/Generating_text_from_trained_models_quran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='run7')

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run7')
# Out:
# Loading checkpoint checkpoint/run7/model-5000
# INFO:tensorflow:Restoring parameters from checkpoint/run7/model-5000

# %% [markdown]
# Generate single text

# %%
gpt2.generate(sess, run_name='run7')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c35f0427484> in <module>()
# ----> 1 gpt2.generate(sess, run_name='run7')
#
# NameError: name 'gpt2' is not defined

# %%
gpt2.generate(sess,
              run_name='run7',
              length=500,
              temperature=0.8,
              prefix=" ",
              nsamples=15,
              batch_size=5
              )
# Out:
#  يهربوا في السماوات و هو كل ما له الرب بدمه. و قال ان بالسخط ارفعوا اخذوا اصواتي و حاربوا جميع اعدائكم و قضوا عليهم صوتا للفحص و كانوا يخاطبون المصورين بهجة عظيمة ذي اقسم و يفرحون في يدهم صاحب خارج من يد الهتهم لانهم لا يموت. و قال يوناتان للخطية ان تفكروا و تمضي عليهم بالمكان الذي يصيرونه. فاتى اليه يوناتان و قال هل اضطرت لهم مجد يوناتان و لكن ليس لهم اليوم بل في مودتهم صوت قنطان قبل ان يحملوهم بالاناشيات لان الله يهدم على الموت. فاثبت لهم سليمان بايمان و جاء اليه ليخطئ ان يزال و لا تكون نقصة للفط
# ...
